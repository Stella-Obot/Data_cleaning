# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("my exel2")
df.head(21)
# Out:
#     Ansa  Clingo  new_creation
# 0      3       6             3
# 1      3       1             1
# 2      8       4             1
# 3      1      10             0
# 4      3       8             3
# 5      5       4             3
# 6      8       3             2
# 7      6       9             1
# 8      4       9             7
# 9      5       2             5
# 10     4       1             5
# 11     6       3             0
# 12     1       2             3
# 13     7       4             0
# 14     7       6             5
# 15     5       9             2
# 16     4       6             5
# 17     4       2             3
# 18     8       1             3
# 19     2       7             1
# 20     6      10             6

# %%
#Rating Distribution
plt.rc("font", size = 15)
Rating.Ansa.value_count(sort = false).plot(kind = 'bar')
plt.title('Rating Distribution\n')
plt.xlabel('Rating')
plt.ylabel('count')
plt.savefig('system1.png',bbox_inches = 'tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-ab2a26d27cf0> in <module>()
#       1 #Rating Distribution
#       2 plt.rc("font", size = 15)
# ----> 3 Rating.Ansa.value_count(sort = false).plot(kind = 'bar')
#       4 plt.title('Rating Distribution\n')
#       5 plt.xlabel('Rating')
#
# NameError: name 'Rating' is not defined
